# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\02_nav_history.csv"
)

print(df.head())
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[ns]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.1 MB

# %%
df.isnull().mean()
# Out:
# amfi_code    0.0
# date         0.0
# nav          0.0
# dtype: float64

# %%
df=df.sort_values(['amfi_code','date'])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['nav'].isnull().mean()*100
# Out:
# 0.0

# %%
df['nav'] = (
    df.groupby('amfi_code')['nav']
      .ffill()
)

# %%
invalid_nav = df[df['nav'] <= 0]

print(invalid_nav)
# Out:
# Empty DataFrame
# Columns: [amfi_code, date, nav]
# Index: []

# %%
df = df[df['nav'] > 0]

# %%
df.to_csv(
    r"C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\processed\nav_history_clean.csv",
    index=False
)

# %% [markdown]
# **********
# # Clean investor_transactions.csv — standardise transaction_type values (SIP/Lumpsum/Redemption), validate amount > 0, fix date formats, check KYC status enum values.
