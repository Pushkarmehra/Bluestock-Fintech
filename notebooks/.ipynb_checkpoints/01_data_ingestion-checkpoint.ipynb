# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df_day1 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\01_fund_master.csv')
df_day2 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\02_nav_history.csv')
df_day3 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\03_aum_by_fund_house.csv')
df_day4 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\04_monthly_sip_inflows.csv')
df_day5 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\05_category_inflows.csv')
df_day6 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\06_industry_folio_count.csv')
df_day7 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\07_scheme_performance.csv')
df_day8 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\08_investor_transactions.csv')
df_day9 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\09_portfolio_holdings.csv')
df_day10 = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\10_benchmark_indices.csv')

# %%
dfs = [df_day1, df_day2, df_day3, df_day4, df_day5,df_day6, df_day7, df_day8, df_day9, df_day10]
count=1
for i in dfs:
    print("df_day",count,i.shape,'shape')
    count+=1
# Out:
# df_day 1 (40, 15) shape
# df_day 2 (46000, 3) shape
# df_day 3 (90, 5) shape
# df_day 4 (48, 6) shape
# df_day 5 (144, 3) shape
# df_day 6 (21, 6) shape
# df_day 7 (40, 19) shape
# df_day 8 (32778, 13) shape
# df_day 9 (322, 8) shape
# df_day 10 (8050, 3) shape

# %%
count=1
for i in dfs:
    print('*'*50)
    print(' '*20,"df_day",count,)
    print(i.dtypes,'dtype')
    count+=1
    print('*'*50)
    print('\n'*2)
# Out:
# **************************************************
#                      df_day 1
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object dtype
# **************************************************
#
#
#
# **************************************************
#                      df_day 2
# amfi_code      int64
# date          object
# nav          float64
# dtype: object dtype
# **************************************************
#
#
#
# **************************************************
#                      df_day 3
# date               object
# ...

# %%
count=1
for i in dfs:
    print('*'*50)
    print(' '*20,"df_day",count,)
    print(i.head(),'First 5 Elments')
    count+=1
    print('*'*50)
    print('\n'*2)
# Out:
# **************************************************
#                      df_day 1
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# ...

# %% [markdown]
# *********************************************************************************
#  ## 1. anomalies that i have found is that the  columns like date,month,some category should have been have differnt dtype which can effect there size and how to deal with certain datatype or columns and make it easy to see

# %% [markdown]
# ![image.png](attachment:ed94dc8e-799f-471b-8f72-251a3af85ac5.png)

# %%
import pandas as pd
fund_master = pd.read_csv(
    r"C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\01_fund_master.csv"
)

# %%
fund_master.isnull().mean()
# Out:
# amfi_code             0.0
# fund_house            0.0
# scheme_name           0.0
# category              0.0
# sub_category          0.0
# plan                  0.0
# launch_date           0.0
# benchmark             0.0
# expense_ratio_pct     0.0
# exit_load_pct         0.0
# min_sip_amount        0.0
# min_lumpsum_amount    0.0
# fund_manager          0.0
# risk_category         0.0
# sebi_category_code    0.0
# dtype: float64

# %%
fund_master.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')

# %%
fund_master['fund_house'].unique()
# Out:
# array(['SBI Mutual Fund', 'HDFC Mutual Fund', 'ICICI Prudential MF',
#        'Nippon India MF', 'Kotak Mahindra MF', 'Axis Mutual Fund',
#        'Aditya Birla Sun Life MF', 'UTI Mutual Fund', 'Mirae Asset MF',
#        'DSP Mutual Fund'], dtype=object)

# %%
fund_master['category'].unique()
# Out:
# array(['Equity', 'Debt'], dtype=object)

# %%
fund_master['sub_category'].unique()
# Out:
# array(['Large Cap', 'Small Cap', 'Gilt', 'Mid Cap', 'Short Duration',
#        'Value', 'Liquid', 'Index/ETF', 'Flexi Cap', 'Index',
#        'Large & Mid Cap', 'ELSS'], dtype=object)

# %%
fund_master['risk_category'].unique()
# Out:
# array(['Moderate', 'Very High', 'Low', 'High', 'Moderately High'],
#       dtype=object)

# %% [markdown]
# ![image.png](attachment:83ac13cb-a1aa-4adc-bfe1-00cee9107631.png)

# %%
nav_history = pd.read_csv(r'C:\Users\pushk\OneDrive\Desktop\AIML\Blue Stocks\mutual-fund-analytics\data\raw\02_nav_history.csv')

# %%
nav_history['amfi_code'].value_counts()
# Out:
# amfi_code
# 119551    1150
# 119552    1150
# 120843    1150
# 120844    1150
# 119092    1150
# 119093    1150
# 119094    1150
# 119095    1150
# 101206    1150
# 101207    1150
# 101208    1150
# 102885    1150
# 102886    1150
# 102887    1150
# 148567    1150
# 148568    1150
# 148569    1150
# 149322    1150
# 149323    1150
# 120842    1150
# 120841    1150
# 118636    1150
# 100025    1150
# 119598    1150
# 119599    1150
# 119120    1150
# 100016    1150
# 125497    1150
# 100033    1150
# 125498    1150
# 120503    1150
# 118635    1150
# 120504    1150
# 120505    1150
# 120506    1150
# 120507    1150
# 118632    1150
# 118633    1150
# 118634    1150
# 149324    1150
# Name: count, dtype: int64

# %%
fund_master['amfi_code'].value_counts()
# Out:
# amfi_code
# 119551    1
# 119552    1
# 120843    1
# 120844    1
# 119092    1
# 119093    1
# 119094    1
# 119095    1
# 101206    1
# 101207    1
# 101208    1
# 102885    1
# 102886    1
# 102887    1
# 148567    1
# 148568    1
# 148569    1
# 149322    1
# 149323    1
# 120842    1
# 120841    1
# 118636    1
# 100025    1
# 119598    1
# 119599    1
# 119120    1
# 100016    1
# 125497    1
# 100033    1
# 125498    1
# 120503    1
# 118635    1
# 120504    1
# 120505    1
# 120506    1
# 120507    1
# 118632    1
# 118633    1
# 118634    1
# 149324    1
# Name: count, dtype: int64

# %%
nav_list=list(set(nav_history['amfi_code']))

# %%
fund_list=list(set(fund_master['amfi_code']))

# %%
len(fund_list)
# Out:
# 40

# %%
len(nav_list)
# Out:
# 40

# %%
for i in range(0,len(nav_list),1):
    if nav_list[i]==fund_list[i]:
        print('present')
    else:
        print('missed')
# Out:
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present
# present

# %% [markdown]
# ## Data Quality Summary
#
# I checked all the datasets after loading them into Pandas. I looked for missing values, duplicate records, incorrect data types, and formatting issues. I found some minor problems such as inconsistent date formats and different spellings/cases of transaction types like SIP and sip. I also verified that the AMFI codes in the fund master dataset matched the codes available in the NAV history data. No major data quality issues were found. Overall, the data is in good condition and only needs some basic cleaning and standardization before further analysis.
